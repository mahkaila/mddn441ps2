# %%
from IPython.display import Image
from IPython.display import HTML

# %%
# !mkdir temp/wes

command = "ffmpeg -i inputs/moonrise.mp4 -vf fps=1 temp/wes/moon%04d.jpg -hide_banner"
# !{command}

command = "ffmpeg -i inputs/budapest.mp4 -vf fps=1 temp/wes/budapest%04d.jpg -hide_banner"
# !{command}

command = "ffmpeg -i inputs/fox.mp4 -vf fps=1 temp/wes/fox%04d.jpg -hide_banner"
# !{command}

command = "ffmpeg -i inputs/royal.mp4 -vf fps=1 temp/wes/royal%04d.jpg -hide_banner"
# !{command}

command = "ffmpeg -i inputs/rushmore.mp4 -vf fps=1 temp/wes/rushmore%04d.jpg -hide_banner"
# !{command}
# Out:
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'inputs/moonrise.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2016-03-10 17:24:52
#   Duration: 00:01:56.84, start: 0.000000, bitrate: 539 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 441 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       creation_time   : 2016-03-10 17:24:52
#       handler_name    : IsoMedia File Produced by Google, 5-11-2011
# [swscaler @ 0x7f8940826c00] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'temp/wes/moon%04d.jpg':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
# ...

# %%
# !mkdir temp/drake

command = "ffmpeg -i inputs/bling.mp4 temp/drake/img_%04d.jpg -hide_banner"
# !{command}
# Out:
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'inputs/bling.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2017-07-26 12:35:17
#   Duration: 00:04:55.57, start: 0.000000, bitrate: 392 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 293 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       creation_time   : 2017-07-26 12:35:18
#       handler_name    : IsoMedia File Produced by Google, 5-11-2011
# [swscaler @ 0x7fe624000000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'temp/drake/img_%04d.jpg':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
# ...

# %%
# !wget -O inputs/aha.jpg \
  https://ewedit.files.wordpress.com/2015/10/a-ha-take-on-me.jpg?w=612

# %%
from IPython.display import Image
from IPython.display import HTML

# !wget -O inputs/moon.jpg \
  https://github.com/titu1994/Neural-Style-Transfer/raw/master/images/inputs/content/blue-moon-lake.jpg
# !wget -O inputs/starry.jpg \
  https://github.com/titu1994/Neural-Style-Transfer/raw/master/images/inputs/style/starry_night.jpg        

# !python /usr/local/anaconda/extras/Neural-Style-Transfer/INetwork.py \
    --image_size 110 \
    inputs/moon.jpg \
    inputs/starry.jpg \
    outputs/starry_moon.jpg

Image("outputs/starry_moon.jpg_at_iteration_10.png")
