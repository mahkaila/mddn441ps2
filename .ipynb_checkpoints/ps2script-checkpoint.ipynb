# %%
from IPython.display import Image
from IPython.display import HTML

# %%
# !mkdir temp/wes2

command = "ffmpeg -i inputs/moonrise.mp4 -vf fps=1 temp/wes2/img_%04d.jpg -hide_banner"
# !{command}

command = "ffmpeg -i inputs/budapest.mp4 -vf fps=1 temp/wes2/img_%04d.jpg -hide_banner"
# !{command}

command = "ffmpeg -i inputs/fox.mp4 -vf fps=1 temp/wes2/img_%04d.jpg -hide_banner"
# !{command}

command = "ffmpeg -i inputs/royal.mp4 -vf fps=1 temp/wes2/img_%04d.jpg -hide_banner"
# !{command}

command = "ffmpeg -i inputs/rushmore.mp4 -vf fps=1 temp/wes2/img_%04d.jpg -hide_banner"
# !{command}
# Out:
# /bin/sh: ffmpeg: command not found
# /bin/sh: ffmpeg: command not found
# /bin/sh: ffmpeg: command not found
# /bin/sh: ffmpeg: command not found
# /bin/sh: ffmpeg: command not found

# %%
# !mkdir temp/drake

command = "ffmpeg -i inputs/bling.mp4 temp/drake/img_%04d.jpg -hide_banner"
# !{command}
# Out:
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'inputs/bling.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2017-07-26 12:35:17
#   Duration: 00:04:55.57, start: 0.000000, bitrate: 392 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 293 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       creation_time   : 2017-07-26 12:35:18
#       handler_name    : IsoMedia File Produced by Google, 5-11-2011
# [swscaler @ 0x7fe624000000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'temp/drake/img_%04d.jpg':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf56.25.101
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc56.26.100 mjpeg
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# frame= 7085 fps=412 q=24.8 Lsize=N/A time=00:04:55.50 bitrate=N/A
# video:44008kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !wget -O inputs/aha.jpg \
  https://ewedit.files.wordpress.com/2015/10/a-ha-take-on-me.jpg?w=612

# %%
# !wget -O inputs/aha.jpg \
  https://ewedit.files.wordpress.com/2015/10/a-ha-take-on-me.jpg?w=612       

# !python /usr/local/anaconda/extras/Neural-Style-Transfer/INetwork.py \
    --image_size 110 \
    temp/drake/img_4801.jpg \
    inputs/aha.jpg \
    outputs/drake_aha.jpg

Image("outputs/starry_moon.jpg_at_iteration_10.png")
# Out:
# --2017-08-24 16:04:02--  https://ewedit.files.wordpress.com/2015/10/a-ha-take-on-me.jpg?w=612
# Resolving ewedit.files.wordpress.com... 192.0.72.26, 192.0.72.27
# Connecting to ewedit.files.wordpress.com|192.0.72.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 177371 (173K) [image/jpeg]
# Saving to: ‘inputs/aha.jpg’
#
# inputs/aha.jpg      100%[===================>] 173.21K  --.-KB/s    in 0.1s
#
# 2017-08-24 16:04:03 (1.20 MB/s) - ‘inputs/aha.jpg’ saved [177371/177371]
#
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# WARNING (theano.sandbox.cuda): CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: CUDA driver version is insufficient for CUDA runtime version)
# Model loaded.
# Starting iteration 1 of 10
# Current loss value: 242757600.0  Improvement : 0.000 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_1.png
# Iteration 1 completed in 43s
# Starting iteration 2 of 10
# Current loss value: 136197904.0  Improvement : 43.896 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_2.png
# Iteration 2 completed in 42s
# Starting iteration 3 of 10
# Current loss value: 95198960.0  Improvement : 30.102 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_3.png
# Iteration 3 completed in 41s
# Starting iteration 4 of 10
# Current loss value: 74117984.0  Improvement : 22.144 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_4.png
# Iteration 4 completed in 41s
# Starting iteration 5 of 10
# Current loss value: 59933412.0  Improvement : 19.138 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_5.png
# Iteration 5 completed in 41s
# Starting iteration 6 of 10
# Current loss value: 51494340.0  Improvement : 14.081 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_6.png
# Iteration 6 completed in 42s
# Starting iteration 7 of 10
# Current loss value: 45035544.0  Improvement : 12.543 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_7.png
# Iteration 7 completed in 42s
# Starting iteration 8 of 10
# Current loss value: 39653636.0  Improvement : 11.950 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_8.png
# Iteration 8 completed in 42s
# Starting iteration 9 of 10
# Current loss value: 35573124.0  Improvement : 10.290 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_9.png
# Iteration 9 completed in 41s
# Starting iteration 10 of 10
# Current loss value: 32222924.0  Improvement : 9.418 %
# Rescaling Image to (110, 195)
# Image saved as outputs/drake_aha.jpg_at_iteration_10.png
# Iteration 10 completed in 42s

# %%
from IPython.display import Image
from IPython.display import HTML

# !wget -O inputs/moon.jpg \
  https://github.com/titu1994/Neural-Style-Transfer/raw/master/images/inputs/content/blue-moon-lake.jpg
# !wget -O inputs/starry.jpg \
  https://github.com/titu1994/Neural-Style-Transfer/raw/master/images/inputs/style/starry_night.jpg        

# !python /usr/local/anaconda/extras/Neural-Style-Transfer/INetwork.py \
    --image_size 110 \
    inputs/moon.jpg \
    inputs/starry.jpg \
    outputs/starry_moon.jpg

Image("outputs/starry_moon.jpg_at_iteration_10.png")
# Out:
# --2017-08-24 15:54:36--  https://github.com/titu1994/Neural-Style-Transfer/raw/master/images/inputs/content/blue-moon-lake.jpg
# Resolving github.com... 192.30.255.113, 192.30.255.112
# Connecting to github.com|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/titu1994/Neural-Style-Transfer/master/images/inputs/content/blue-moon-lake.jpg [following]
# --2017-08-24 15:54:37--  https://raw.githubusercontent.com/titu1994/Neural-Style-Transfer/master/images/inputs/content/blue-moon-lake.jpg
# Resolving raw.githubusercontent.com... 151.101.164.133
# Connecting to raw.githubusercontent.com|151.101.164.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102728 (100K) [image/jpeg]
# Saving to: ‘inputs/moon.jpg’
#
# inputs/moon.jpg     100%[===================>] 100.32K  --.-KB/s    in 0.03s
#
# 2017-08-24 15:54:37 (3.47 MB/s) - ‘inputs/moon.jpg’ saved [102728/102728]
#
# --2017-08-24 15:54:37--  https://github.com/titu1994/Neural-Style-Transfer/raw/master/images/inputs/style/starry_night.jpg
# Resolving github.com... 192.30.255.113, 192.30.255.112
# Connecting to github.com|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/titu1994/Neural-Style-Transfer/master/images/inputs/style/starry_night.jpg [following]
# --2017-08-24 15:54:38--  https://raw.githubusercontent.com/titu1994/Neural-Style-Transfer/master/images/inputs/style/starry_night.jpg
# Resolving raw.githubusercontent.com... 151.101.164.133
# Connecting to raw.githubusercontent.com|151.101.164.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 186457 (182K) [image/jpeg]
# Saving to: ‘inputs/starry.jpg’
#
# inputs/starry.jpg   100%[===================>] 182.09K  --.-KB/s    in 0.04s
#
# 2017-08-24 15:54:38 (4.76 MB/s) - ‘inputs/starry.jpg’ saved [186457/186457]
#
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# WARNING (theano.sandbox.cuda): CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: CUDA driver version is insufficient for CUDA runtime version)
# Model loaded.
# Starting iteration 1 of 10
# Current loss value: 245802944.0  Improvement : 0.000 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_1.png
# Iteration 1 completed in 31s
# Starting iteration 2 of 10
# Current loss value: 125965680.0  Improvement : 48.753 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_2.png
# Iteration 2 completed in 31s
# Starting iteration 3 of 10
# Current loss value: 89730232.0  Improvement : 28.766 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_3.png
# Iteration 3 completed in 36s
# Starting iteration 4 of 10
# Current loss value: 70061200.0  Improvement : 21.920 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_4.png
# Iteration 4 completed in 38s
# Starting iteration 5 of 10
# Current loss value: 58018776.0  Improvement : 17.188 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_5.png
# Iteration 5 completed in 38s
# Starting iteration 6 of 10
# Current loss value: 49913480.0  Improvement : 13.970 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_6.png
# Iteration 6 completed in 38s
# Starting iteration 7 of 10
# Current loss value: 44239952.0  Improvement : 11.367 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_7.png
# Iteration 7 completed in 38s
# Starting iteration 8 of 10
# Current loss value: 40593024.0  Improvement : 8.244 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_8.png
# Iteration 8 completed in 38s
# Starting iteration 9 of 10
# Current loss value: 37941644.0  Improvement : 6.532 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_9.png
# Iteration 9 completed in 38s
# Starting iteration 10 of 10
# Current loss value: 34847736.0  Improvement : 8.154 %
# Rescaling Image to (110, 176)
# Image saved as outputs/starry_moon.jpg_at_iteration_10.png
# Iteration 10 completed in 38s
